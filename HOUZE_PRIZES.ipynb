# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_csv("test.csv")
train_data = pd.read_csv("train.csv", index_col='Id')

# %%
Y_train = train_data['SalePrice']
X_train = train_data.drop('SalePrice', axis = 1)

# %%
Y_train.dtypes
# Out:
# dtype('int64')

# %%
X_train.dtypes.head(10)
X_train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
t_X_train = pd.get_dummies(X_train, columns = ['MSZoning','Street','Alley','LotShape','LandContour', 'Utilities','LotConfig','LandSlope','Neighborhood','Street','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition'])

# %%
from sklearn.neighbors import KNeighborsClassifier
kn_classifier = KNeighborsClassifier(n_jobs = -1, n_neighbors = 11, weights = 'distance')
kn_classifier.fit(t_X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-c218b8882453> in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 kn_classifier = KNeighborsClassifier(n_jobs = -1, n_neighbors = 11, weights = 'distance')
# ----> 3 kn_classifier.fit(t_X_train, Y_train)
#
# E:\Anaconda\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     890         """
#     891         if not isinstance(X, (KDTree, BallTree)):
# --> 892             X, y = check_X_y(X, y, "csr", multi_output=True)
#     893
#     894         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
from sklearn.metrics import accuracy_score
kn_predictions = kn_classifier.predict(train_data)
accuracy_score(train_label, kn_predictions)
